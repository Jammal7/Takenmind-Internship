# %% [markdown]
# ## Mapping in DataFrame

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'country': ['USA', 'China', 'Nigeria', 'Ghana', 'Japan'],
    'GDP': [19,12,45,40,4]
})
print(df)
# Out:
#    country  GDP
# 0      USA   19
# 1    China   12
# 2  Nigeria   45
# 3    Ghana   40
# 4    Japan    4

# %%
population_map = {
    'USA': 325,
    'China': 1421,
    'Nigeria': 1200,
    'Ghana': 8675,
    'Japan': 127
}
print(populaion_map)
# Out:
# {'USA': 325, 'China': 1421, 'Nigeria': 1200, 'Ghana': 8675, 'Japan': 127}

# %%
df['population'] = df['country'].map(population_map)

# %%
print(df)
# Out:
#    country  GDP  population
# 0      USA   19         325
# 1    China   12        1421
# 2  Nigeria   45        1200
# 3    Ghana   40        8675
# 4    Japan    4         127

# %% [markdown]
# ## Replacing Values in Series

# %%
s1 = pd.Series([10,20,40,50,20,10,50,40])
print(s1)
# Out:
# 0    10
# 1    20
# 2    40
# 3    50
# 4    20
# 5    10
# 6    50
# 7    40
# dtype: int64

# %%
s1.replace(10, np.nan)
# Out:
# 0     NaN
# 1    20.0
# 2    40.0
# 3    50.0
# 4    20.0
# 5     NaN
# 6    50.0
# 7    40.0
# dtype: float64

# %%
s1.replace([10,20,40],[100,np.nan,80])
# Out:
# 0    100.0
# 1      NaN
# 2     80.0
# 3     50.0
# 4      NaN
# 5    100.0
# 6     50.0
# 7     80.0
# dtype: float64

# %%
s1.replace({10:100, 20:np.nan,40:5})
# Out:
# 0    100.0
# 1      NaN
# 2      5.0
# 3     50.0
# 4      NaN
# 5    100.0
# 6     50.0
# 7      5.0
# dtype: float64

# %% [markdown]
# ## Renaming Indexes in DataFrame

# %%
df = pd.DataFrame(np.arange(6).reshape(3,2), index=['AUDI','MERCEDEZ','TOYOTA'],
                 columns=['PERFORMANCE','SAFETY'])
print(df)
# Out:
#           PERFORMANCE  SAFETY
# AUDI                0       1
# MERCEDEZ            2       3
# TOYOTA              4       5

# %%
#rename index using mapping
df.index = df.index.map(str.lower)
print(df)
# Out:
#           PERFORMANCE  SAFETY
# audi                0       1
# mercedez            2       3
# toyota              4       5

# %%
#using rename()
df.rename(index=str.title, columns=str.lower)
# Out:
#           performance  safety
# Audi                0       1
# Mercedez            2       3
# Toyota              4       5

# %%
#using dict()
df.rename(index={'audi':'BMW'}, columns={'SAFETY':'SAFETY_TEST'})
# Out:
#           PERFORMANCE  SAFETY_TEST
# BMW                 0            1
# mercedez            2            3
# toyota              4            5

# %%
#saving the renamed dataframe
df.rename(index={'audi':'BMW'}, columns={'SAFETY':'SAFETY_TEST'}, inplace=True)

# %%
df
# Out:
#           PERFORMANCE  SAFETY_TEST
# BMW                 0            1
# mercedez            2            3
# toyota              4            5

# %% [markdown]
# ## Observation, Filtering and Basic Analysis

# %%
sf = pd.DataFrame(np.random.randn(500,15))
print(sf)
# Out:
#             0         1         2         3         4         5         6  \
# 0   -1.172448  0.099838  0.181067  0.564849 -1.656076 -0.211645  1.024982
# 1    0.292094 -2.023148 -1.461970  1.155323  0.827056 -0.527078 -0.009753
# 2   -0.227213  0.412330  3.113138  1.172147  0.690827  1.026349 -0.446573
# 3    0.682457 -0.408647  1.697106  0.613023 -0.168163  0.442301  1.005778
# 4    1.515870  0.184545  0.071818  1.561611 -1.057839  3.376868 -0.932389
# ..        ...       ...       ...       ...       ...       ...       ...
# 495 -0.558746 -0.136744  1.333167 -0.357775  1.069702  0.387742 -0.395702
# 496  0.483703  1.297169 -0.371555 -0.534383  0.736265  0.678770 -0.534296
# 497  0.064542  0.022378  0.150757 -0.190905 -1.635441  0.180622  1.220998
# 498 -0.292934 -1.536518 -0.518052  0.825119  0.639694 -0.444779 -0.030799
# 499 -0.014370 -0.053699 -0.756568  1.747685  0.548369  0.536716 -0.006499
#
#             7         8         9        10        11        12        13  \
# 0    2.347366 -0.199224  0.718426 -0.636608  1.048696 -1.769344 -1.275757
# 1    0.663447  0.864869 -0.117899 -2.109856 -0.316312  0.689120  0.382655
# 2    0.101232 -0.834067 -0.699639 -1.431328  1.663321 -0.373343 -1.113498
# 3    1.052443  2.345013 -0.822992  0.976844  0.840532  0.319822  1.125615
# 4    0.184844  1.449025 -0.001372 -0.706906 -0.128929 -0.537589 -1.868327
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.098728 -2.222879 -0.627499 -0.156468 -0.510173  1.087648  2.077701
# 496 -1.170976 -0.280879 -0.052210 -2.270639 -0.241981 -1.830061 -2.703369
# 497  0.571642 -0.647836  1.141622  0.213688 -0.425664 -0.041659 -0.167270
# 498 -0.586137  0.264001 -0.382432 -1.511416 -1.479268 -0.937196 -0.892603
# 499  0.462169 -0.656371  0.379333 -1.325323 -1.069886  1.100528 -1.130386
#
#            14
# 0   -1.230106
# 1    0.192703
# 2    1.087825
# 3   -0.665188
# 4   -1.934202
# ..        ...
# 495  1.241741
# 496  0.138135
# 497 -0.692623
# 498  0.331664
# 499 -1.514263
#
# [500 rows x 15 columns]

# %%
sf.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.172448  0.099838  0.181067  0.564849 -1.656076 -0.211645  1.024982
# 1  0.292094 -2.023148 -1.461970  1.155323  0.827056 -0.527078 -0.009753
# 2 -0.227213  0.412330  3.113138  1.172147  0.690827  1.026349 -0.446573
# 3  0.682457 -0.408647  1.697106  0.613023 -0.168163  0.442301  1.005778
# 4  1.515870  0.184545  0.071818  1.561611 -1.057839  3.376868 -0.932389
#
#           7         8         9        10        11        12        13  \
# 0  2.347366 -0.199224  0.718426 -0.636608  1.048696 -1.769344 -1.275757
# 1  0.663447  0.864869 -0.117899 -2.109856 -0.316312  0.689120  0.382655
# 2  0.101232 -0.834067 -0.699639 -1.431328  1.663321 -0.373343 -1.113498
# 3  1.052443  2.345013 -0.822992  0.976844  0.840532  0.319822  1.125615
# 4  0.184844  1.449025 -0.001372 -0.706906 -0.128929 -0.537589 -1.868327
#
#          14
# 0 -1.230106
# 1  0.192703
# 2  1.087825
# 3 -0.665188
# 4 -1.934202

# %%
sf.tail()
# Out:
#             0         1         2         3         4         5         6  \
# 495 -0.558746 -0.136744  1.333167 -0.357775  1.069702  0.387742 -0.395702
# 496  0.483703  1.297169 -0.371555 -0.534383  0.736265  0.678770 -0.534296
# 497  0.064542  0.022378  0.150757 -0.190905 -1.635441  0.180622  1.220998
# 498 -0.292934 -1.536518 -0.518052  0.825119  0.639694 -0.444779 -0.030799
# 499 -0.014370 -0.053699 -0.756568  1.747685  0.548369  0.536716 -0.006499
#
#             7         8         9        10        11        12        13  \
# 495  0.098728 -2.222879 -0.627499 -0.156468 -0.510173  1.087648  2.077701
# 496 -1.170976 -0.280879 -0.052210 -2.270639 -0.241981 -1.830061 -2.703369
# 497  0.571642 -0.647836  1.141622  0.213688 -0.425664 -0.041659 -0.167270
# 498 -0.586137  0.264001 -0.382432 -1.511416 -1.479268 -0.937196 -0.892603
# 499  0.462169 -0.656371  0.379333 -1.325323 -1.069886  1.100528 -1.130386
#
#            14
# 495  1.241741
# 496  0.138135
# 497 -0.692623
# 498  0.331664
# 499 -1.514263

# %%
sf.describe()
# Out:
#                0           1           2           3           4           5   \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean    -0.015433   -0.072714   -0.032174   -0.025373   -0.037732    0.030550
# std      0.959063    1.029592    1.028893    0.974965    1.029128    0.988875
# min     -3.635580   -2.777975   -2.568318   -3.433818   -2.723063   -3.164747
# 25%     -0.640026   -0.768801   -0.789046   -0.676316   -0.697760   -0.607680
# 50%     -0.029495   -0.046384   -0.081629   -0.013786   -0.031928    0.021838
# 75%      0.670434    0.686673    0.656235    0.630744    0.647882    0.665722
# max      2.850001    2.665711    4.094569    3.126341    3.083438    3.376868
#
#                6           7           8           9           10          11  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean    -0.008806   -0.004605   -0.062602   -0.022445    0.008470   -0.091699
# std      1.002396    1.006566    1.062138    0.974789    0.986960    0.948998
# min     -4.083320   -3.200050   -2.919987   -2.514883   -2.794734   -2.791021
# 25%     -0.639426   -0.692666   -0.727036   -0.726271   -0.672399   -0.762732
# 50%     -0.034885    0.009564   -0.039143   -0.009291   -0.019734   -0.124560
# 75%      0.648963    0.663632    0.639731    0.617955    0.681812    0.548876
# max      3.460779    2.737832    4.038371    2.703832    3.146131    2.834542
#
#                12          13          14
# count  500.000000  500.000000  500.000000
# mean    -0.019849   -0.049113    0.002508
# std      0.961219    1.035212    1.049923
# min     -2.966028   -3.591270   -3.335489
# 25%     -0.688560   -0.805513   -0.691955
# 50%     -0.017751   -0.095795    0.006263
# 75%      0.663403    0.653331    0.698257
# max      2.871876    2.905753    3.409796

# %%
column1 = sf[0]
print(column1.head())
# Out:
# 0   -1.172448
# 1    0.292094
# 2   -0.227213
# 3    0.682457
# 4    1.515870
# Name: 0, dtype: float64

# %%
column1[np.abs(column1) > 2.5]
# Out:
# 8      2.850001
# 126   -3.635580
# 315   -2.596071
# 373   -2.837295
# 431   -2.668993
# Name: 0, dtype: float64

# %%
sf[(np.abs(sf)>2.5).any(1)]
# Out:
#             0         1         2         3         4         5         6  \
# 2   -0.227213  0.412330  3.113138  1.172147  0.690827  1.026349 -0.446573
# 4    1.515870  0.184545  0.071818  1.561611 -1.057839  3.376868 -0.932389
# 8    2.850001 -0.627405 -0.804870 -1.664825 -0.829341  0.098320  1.729049
# 13  -0.620083 -0.462748 -0.106286 -0.100635  0.935154  1.754127  1.600170
# 14  -0.948927 -0.090299 -2.188996  1.120945 -0.711530 -1.185999 -1.674406
# ..        ...       ...       ...       ...       ...       ...       ...
# 482 -0.066448  0.167904 -1.207611  0.169587 -1.355780 -0.744299  1.760613
# 488  0.581943 -2.514911 -1.365720  0.157333 -0.963865  1.432690  0.632552
# 490 -0.299960 -0.541831 -1.520478 -1.040931  0.796792 -0.986360 -0.583923
# 494  1.209538  0.425729 -0.497200  1.139284 -0.846956 -1.295643 -1.535936
# 496  0.483703  1.297169 -0.371555 -0.534383  0.736265  0.678770 -0.534296
#
#             7         8         9        10        11        12        13  \
# 2    0.101232 -0.834067 -0.699639 -1.431328  1.663321 -0.373343 -1.113498
# 4    0.184844  1.449025 -0.001372 -0.706906 -0.128929 -0.537589 -1.868327
# 8   -1.925712 -1.598976  0.608591  0.446860  1.612647  1.045053 -0.833156
# 13   0.762451  0.639181  1.732894 -0.358780  1.391085 -0.162976 -0.174933
# 14  -0.068342 -2.856755 -1.039538  1.509921 -0.107192  0.749949 -0.872398
# ..        ...       ...       ...       ...       ...       ...       ...
# 482  1.518504 -2.113408 -0.303475 -1.156545  0.413030 -1.328171  0.804484
# 488  1.225686  0.219330  0.876991  0.133120 -0.654853 -1.208691 -0.618262
# 490 -0.246490  0.541095  1.344979 -0.671163 -1.389456  0.469673 -0.660652
# 494 -1.635610  0.285312 -0.695090 -0.594326 -0.241158  1.048189 -0.407013
# 496 -1.170976 -0.280879 -0.052210 -2.270639 -0.241981 -1.830061 -2.703369
#
#            14
# 2    1.087825
# 4   -1.934202
# 8    0.524035
# 13   3.003531
# 14  -0.711347
# ..        ...
# 482 -2.873916
# 488  0.018591
# 490  2.727678
# 494  2.522482
# 496  0.138135
#
# [97 rows x 15 columns]

# %%
sf[(np.abs(sf)>3)] = np.sign(sf)*5
sf.describe()
# Out:
# C:\Users\DELL INSPIRON 14\anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sign
#   """Entry point for launching an IPython kernel.
#                0           1           2           3           4           5   \
# count  495.000000  494.000000  494.000000  492.000000  489.000000  492.000000
# mean     0.002366   -0.052746   -0.059114   -0.035698   -0.057175    0.018688
# std      0.917491    0.996405    0.976398    0.915159    0.956385    0.927687
# min     -2.477234   -2.484785   -2.444230   -2.274975   -2.467040   -2.399071
# 25%     -0.617855   -0.730943   -0.790585   -0.673003   -0.690325   -0.604609
# 50%     -0.017548   -0.043329   -0.100414   -0.018310   -0.047411    0.021085
# 75%      0.673052    0.688091    0.638636    0.626988    0.608855    0.654040
# max      2.071699    2.476420    2.470189    2.397617    2.442636    2.454360
#
#                6           7           8           9           10          11  \
# count  493.000000  495.000000  488.000000  496.000000  496.000000  497.000000
# mean    -0.002275    0.012642   -0.054926   -0.033723   -0.003044   -0.087253
# std      0.932491    0.971096    0.972982    0.949302    0.957457    0.928493
# min     -2.464054   -2.386052   -2.344278   -2.258634   -2.497446   -2.361858
# 25%     -0.626510   -0.684927   -0.708787   -0.726271   -0.672399   -0.743264
# 50%     -0.034638    0.018530   -0.030262   -0.010378   -0.025398   -0.123452
# 75%      0.647303    0.663818    0.626588    0.608792    0.679161    0.547145
# max      2.201027    2.441781    2.345013    2.388723    2.368956    2.324965
#
#                12          13          14
# count  494.000000  489.000000  489.000000
# mean    -0.019714   -0.042761   -0.015197
# std      0.918784    0.957108    0.966516
# min     -2.194957   -2.494248   -2.456609
# 25%     -0.682845   -0.787230   -0.676387
# 50%     -0.017751   -0.090962    0.001185
# 75%      0.649153    0.639785    0.641687
# max      2.153471    2.317808    2.437566
